# %%
import matplotlib.colors
import matplotlib.pyplot as plt
import numpy as np

# %%
# kleuren huisstijl inladen
logoblauw = matplotlib.colors.to_rgb('#154273')
paars = matplotlib.colors.to_rgb('#42145f')
violet = matplotlib.colors.to_rgb('#a90061')
robijnrood = matplotlib.colors.to_rgb('#ca005d')
roze = matplotlib.colors.to_rgb('#f092cd')
rood = matplotlib.colors.to_rgb('#d52b1e')
oranje = matplotlib.colors.to_rgb('#e17000')
donkergeel = matplotlib.colors.to_rgb('#ffb612')
geel = matplotlib.colors.to_rgb('#f9e11e')
donkerbruin = matplotlib.colors.to_rgb('#673327')
bruin = matplotlib.colors.to_rgb('#94710a')
donkergroen = matplotlib.colors.to_rgb('#275937')
groen = matplotlib.colors.to_rgb('#39870c')
mosgroen = matplotlib.colors.to_rgb('#777b00')
mintgroen = matplotlib.colors.to_rgb('#76d2b6')
donkerblauw = matplotlib.colors.to_rgb('#01689b')
hemelblauw = matplotlib.colors.to_rgb('#007bc7')
lichtblauw = matplotlib.colors.to_rgb('#8fcae7')
grijs_1 = matplotlib.colors.to_rgb('#f3f3f3')
grijs_2 = matplotlib.colors.to_rgb('#e6e6e6')
grijs_3 = matplotlib.colors.to_rgb('#cccccc')
grijs_4 = matplotlib.colors.to_rgb('#b4b4b4')
grijs_5 = matplotlib.colors.to_rgb('#999999')
grijs_6 = matplotlib.colors.to_rgb('#696969')
grijs_7 = matplotlib.colors.to_rgb('#535353')

# %%
plt.plot([0, 0.25, 0.5, 0.75, 1], c = logoblauw, label = 'logoblauw')
plt.plot([0.1, 0.3, 0.5, 0.7, 0.9], c = paars, label = 'paars')
plt.plot([0.2, 0.35, 0.5, 0.65, 0.8], c = violet, label = 'violet')
plt.plot([0.3, 0.4, 0.5, 0.6, 0.7], c = robijnrood, label = 'robijnrood')
plt.plot([0.4, 0.45, 0.5, 0.55, 0.6], c = roze, label = 'roze')
plt.plot([0.5, 0.5, 0.5, 0.5, 0.5], c = rood, label = 'rood')
plt.plot([0.6, 0.55, 0.5, 0.45, 0.4], c = oranje, label = 'oranje')
plt.plot([0.7, 0.6, 0.5, 0.4, 0.3], c = donkergeel, label = 'donkergeel')
plt.plot([0.8, 0.65, 0.5, 0.35, 0.2], c = geel, label = 'geel')
plt.plot([0.9, 0.7, 0.5, 0.3, 0.1], c = donkerbruin, label = 'donkerbruin')
plt.plot([1, 0.75, 0.5, 0.25, 0], c = bruin, label = 'bruin')
#plt.plot([np.nan, 0.8, 0.5, 0.2, np.nan], c = donkergroen, label = 'donkergroen')
plt.legend()
plt.title('Kleuren van de rijkshuisstijl in Python (Matplotlib)')
plt.show()
